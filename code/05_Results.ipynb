# %%
import matplotlib.pyplot as plt
from PIL import Image

fig, ax = plt.subplots(2,2,figsize=(15,7))

img1 = Image.open("C:/Users/Srinjay Sen/OneDrive/Documents/gw15094 project/figure/01_TimeSeies.png")
ax[0, 0].imshow(img1)
ax[0, 0].set_title('Raw Data')


img2 = Image.open("C:/Users/Srinjay Sen/OneDrive/Documents/gw15094 project/figure/02_Filtering.png")
ax[0, 1].imshow(img2)
ax[0, 1].set_title('Whitened and Filtered Data')

img3 = Image.open("C:/Users/Srinjay Sen/OneDrive/Documents/gw15094 project/figure/03_spectrogram_H1.png")
ax[1, 0].imshow(img3)
ax[1, 0].set_title('Spectrogram for H1 data')

img4 = Image.open("C:/Users/Srinjay Sen/OneDrive/Documents/gw15094 project/figure/04_SNR.png")
ax[1, 1].imshow(img4)
ax[1, 1].set_title('Signal-to-Noise Ratio')


for ax in ax.flat:
    ax.axis('off')




plt.savefig('05_Results.png')
plt.show()
